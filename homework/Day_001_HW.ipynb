# %% [markdown]
# # HW1
# ### Q:請上 Kaggle, 在 Competitions 或 Dataset 中找一組競賽或資料並寫下：
# #### Suicide Rates Overview 1985 to 2016
# ### 1.為什麼這個資料重要?
# #### To find signals correlated to increased suicide rates\n among different cohorts globally, across the socio-economic spectrum.
# ### 2.資料重何而來?
# #### From four other datasets linked by time and place,see reference.
# ### 3.資料的型態是什麼?
# #### csv table.
# ### 4.我們可以回答什麼問題?
# #### Suicide Prevention.
#
# # HW2
# ### Q: 想像你經營一個自由載客車隊，你希望能透過數據分析以提升業績，請你思考並描述你如何規劃整體的分析/解決方案：
# ### 1. 核心問題為何? (tips：如何定義 「提升業績 & 你的假設」)
# * 車隊載客容量(車子數量,營業時間,司機年紀,..)及載客地點,營業區域,通路軟體/電話平均使用成功率,以便精確分析客戶從開始聯絡叫車至成功搭車\n
# 的路線,時間,及當時天氣,交通狀況,車況等一切可能影響業績的變因。例如:APP軟體叫車平均時間與客戶等車時間對回頭客的相關性,利用路線規劃\n
# 減少塞車時間提升客戶滿意度等等。
#
# ### 2. 資料從何而來 (tips：哪些資料可能會對你想問的問題產生影響 & 資料如何蒐集)
# * 將車隊所有車輛裝載 GPS系統，記錄APP登入與成功叫車時間,上下車時間地點,車資; 收集交通路況, 找出容易塞車時間地點,及當時天氣預報紀錄。
#
# ### 3. 蒐集而來的資料型態為何
# * 數值(時間,金錢,里程,速度) 類別(天氣,車輛,客人,司機)等等。
#
# ### 4. 你要回答的問題，其如何評估 (tips：你的假設如何驗證)
# * 提升載客率
#   * 找出特定時間,地點,安排司機於該時間前往附近,減少客戶等候時間。
# * 避開塞車路段
#   * 利用Google行程規劃及行車路況,以最短預估行車時間載客,並確認實際行車時間與預估行車時間誤差最小。
# * 改善叫車所需時間
#   * 設計良好介面,最小化叫車時間,以提升叫車成功率。
#
# ## 練習時間
# #### 請寫一個函式用來計算 Mean Square Error
# $ MSE = \frac{1}{n}\sum_{i=1}^{n}{(Y_i - \hat{Y}_i)^2} $
#
# ### Hint: [如何取平方](https://googoodesign.gitbooks.io/-ezpython/unit-1.html)

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
def mean_squared_error(y,yp):
    """
    Calculate MSE
    Args:
        - y: Real value
        - yp: Prediction value
    Return:
        - mse: MSE
    """
    mse= MSE= sum((y-yp)**2)/len(y)
    return mse

# %%
def mean_absolute_error(y,yp):
    """
    Calculate MAE
    Args:
        - y: Real value
        - yp: Prediction value
    Return:
        - mse: MSE
    """
    mae= MAE= sum(abs(y-yp))/len(y)
    return mae

# %%
w = 3
b = 0.5

x_lin = np.linspace(0, 100, 101)

y = (x_lin + np.random.randn(101) * 5) * w + b

plt.plot(x_lin, y, 'b.', label = 'data points')
plt.title("Assume we have data points")
plt.legend(loc = 2)
plt.show()

# %%
y_hat = x_lin * w + b
plt.plot(x_lin, y, 'b.', label = 'data')
plt.plot(x_lin, y_hat, 'r-', label = 'prediction')
plt.title("Assume we have data points (And the prediction)")
plt.legend(loc = 2)
plt.show()

# %%
# 執行 Function, 確認有沒有正常執行
MSE = mean_squared_error(y, y_hat)
MAE = mean_absolute_error(y, y_hat)
print("The Mean squared error is %.3f" % (MSE))
print("The Mean absolute error is %.3f" % (MAE))
# Out:
# The Mean squared error is 336.343
# The Mean absolute error is 14.846
